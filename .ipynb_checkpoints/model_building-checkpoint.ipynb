# %% [markdown]
# # Project : Car Price Prediction Using ANN Model
#
# ### Objective:
# The objective of this project is to build a machine learning model that predicts the **selling price** of a car based on various features such as the car's name, manufacturing year, current price, kilometers driven, fuel type, seller type, transmission type, and ownership history. This model will help potential sellers or buyers estimate a car’s resale value more accurately.
#
# ### Updated Data Description:
# 1. **Car_Name**: The name or model of the car.
#    - Data Type: `object` (Categorical)
#    - Example: "Maruti Swift"
#
# 2. **Year**: The manufacturing year of the car. This can be used to derive the car's age.
#    - Data Type: `int64`
#    - Example: 2015
#
# 3. **Selling_Price**: The price at which the car was sold (in lakhs of Indian Rupees). This is the target variable for prediction.
#    - Data Type: `float64`
#    - Example: 4.5 (lakhs INR)
#
# 4. **Present_Price**: The current market price of the car (in lakhs of Indian Rupees). It reflects the car's present value based on its condition and market demand.
#    - Data Type: `float64`
#    - Example: 6.7 (lakhs INR)
#
# 5. **Kms_Driven**: The total kilometers the car has been driven. It indicates how much the car has been used, which is an important factor in determining the car's value.
#    - Data Type: `int64`
#    - Example: 40000 (km)
#
# 6. **Fuel_Type**: The type of fuel used by the car.
#    - Data Type: `object` (Categorical)
#    - Possible Values:
#      - `Petrol`
#      - `Diesel`
#      - `CNG`
#
# 7. **Seller_Type**: The type of seller, indicating whether the car is being sold by a dealer or an individual.
#    - Data Type: `object` (Categorical)
#    - Possible Values:
#      - `Dealer`
#      - `Individual`
#
# 8. **Transmission**: The transmission type of the car.
#    - Data Type: `object` (Categorical)
#    - Possible Values:
#      - `Manual`
#      - `Automatic`
#
# 9. **Owner**: The number of previous owners of the car. This feature indicates how many people have owned the car before the current owner.
#    - Data and feature selection to improve model performance.

# %% [markdown]
# # EDA

# %%
# Importing the necessary libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
# Load dataset
df = pd.read_csv("cardekho_dataset.csv")

# %%
df # Displaying the dataset
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# 1          20000  Individual    Petrol            Manual    18.90    1197
# 2          60000  Individual    Petrol            Manual    17.00    1197
# 3          37000  Individual    Petrol            Manual    20.92     998
# 4          30000      Dealer    Diesel            Manual    22.77    1498
# ...          ...         ...       ...               ...      ...     ...
# 15406      10723      Dealer    Petrol            Manual    19.81    1086
# 15407      18000      Dealer    Petrol            Manual    17.50    1373
# 15408      67000      Dealer    Diesel            Manual    21.14    1498
# 15409    3800000      Dealer    Diesel            Manual    16.00    2179
# 15410      13000      Dealer    Petrol         Automatic    18.00    1497
#
#        max_power  seats  selling_price
# 0          46.30      5         120000
# 1          82.00      5         550000
# 2          80.00      5         215000
# 3          67.10      5         226000
# 4          98.59      5         570000
# ...          ...    ...            ...
# 15406      68.05      5         250000
# 15407      91.10      7         925000
# 15408     103.52      5         425000
# 15409     140.00      7        1225000
# 15410     117.60      5        1200000
#
# [15411 rows x 14 columns]

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Feature Engineering
#
# Create a new feature "Age" by using the Year of purchase.

# %%
df.drop(["car_name","brand","model"],axis=1,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 168

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         vehicle_age     km_driven       mileage        engine     max_power  \
# count  15243.000000  1.524300e+04  15243.000000  15243.000000  15243.000000
# mean       6.041265  5.564100e+04     19.697838   1486.114610    100.601958
# std        3.016282  5.176770e+04      4.168978    520.388985     42.911336
# min        0.000000  1.000000e+02      4.000000    793.000000     38.400000
# 25%        4.000000  3.000000e+04     17.000000   1197.000000     74.000000
# 50%        6.000000  5.000000e+04     19.670000   1248.000000     88.500000
# 75%        8.000000  7.000000e+04     22.700000   1582.000000    117.300000
# max       29.000000  3.800000e+06     33.540000   6592.000000    626.000000
#
#               seats  selling_price
# count  15243.000000   1.524300e+04
# mean       5.326183   7.746358e+05
# std        0.808782   8.946687e+05
# min        0.000000   4.000000e+04
# 25%        5.000000   3.850000e+05
# 50%        5.000000   5.590000e+05
# 75%        5.000000   8.250000e+05
# max        9.000000   3.950000e+07

# %%
df.fuel_type.value_counts()
# Out:
# Petrol      7554
# Diesel      7342
# CNG          299
# LPG           44
# Electric       4
# Name: fuel_type, dtype: int64

# %%
df = df[(df["fuel_type"] == "Petrol") | (df["fuel_type"] == "Diesel")]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14896 entries, 0 to 15410
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vehicle_age        14896 non-null  int64
#  1   km_driven          14896 non-null  int64
#  2   seller_type        14896 non-null  object
#  3   fuel_type          14896 non-null  object
#  4   transmission_type  14896 non-null  object
#  5   mileage            14896 non-null  float64
#  6   engine             14896 non-null  int64
#  7   max_power          14896 non-null  float64
#  8   seats              14896 non-null  int64
#  9   selling_price      14896 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 1.3+ MB

# %%
df.fuel_type.value_counts()
# Out:
# Petrol    7554
# Diesel    7342
# Name: fuel_type, dtype: int64

# %%
df.seller_type.value_counts()
# Out:
# Dealer              9224
# Individual          5515
# Trustmark Dealer     157
# Name: seller_type, dtype: int64

# %%
df=df[df["seller_type"] != "Trustmark Dealer"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14739 entries, 0 to 15410
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vehicle_age        14739 non-null  int64
#  1   km_driven          14739 non-null  int64
#  2   seller_type        14739 non-null  object
#  3   fuel_type          14739 non-null  object
#  4   transmission_type  14739 non-null  object
#  5   mileage            14739 non-null  float64
#  6   engine             14739 non-null  int64
#  7   max_power          14739 non-null  float64
#  8   seats              14739 non-null  int64
#  9   selling_price      14739 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 1.2+ MB

# %%
df = pd.get_dummies(df,drop_first=True,dtype="int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14739 entries, 0 to 15410
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   vehicle_age               14739 non-null  int64
#  1   km_driven                 14739 non-null  int64
#  2   mileage                   14739 non-null  float64
#  3   engine                    14739 non-null  int64
#  4   max_power                 14739 non-null  float64
#  5   seats                     14739 non-null  int64
#  6   selling_price             14739 non-null  int64
#  7   seller_type_Individual    14739 non-null  int64
#  8   fuel_type_Petrol          14739 non-null  int64
#  9   transmission_type_Manual  14739 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.2 MB

# %%
X = df.drop("selling_price",axis=1)
Y = df.selling_price

# %%
# RFE Method
model = LinearRegression()
rfe = RFE(model)
fit  = rfe.fit(X,Y)

# %%
fit.n_features_
# Out:
# 4

# %%
fit.ranking_
# Out:
# array([1, 6, 2, 5, 1, 1, 4, 3, 1])

# %%
fit.support_
# Out:
# array([ True, False, False, False,  True,  True, False,  True])

# %%
X.columns
# Out:
# Index(['vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power', 'seats',
#        'seller_type_Individual', 'fuel_type_Petrol',
#        'transmission_type_Manual'],
#       dtype='object')

# %%
model = DecisionTreeRegressor()
model.fit(X,Y)
# Out:
# DecisionTreeRegressor()

# %%
(model.feature_importances_)
# Out:
# array([0.15913941, 0.046615  , 0.14472781, 0.05060351, 0.58641926,
#        0.00404615, 0.00152151, 0.00134824, 0.0055791 ])

# %%
import ppscore as pps

# %%
pp_score = pps.matrix(df)

# %%
pp_score = pp_score[["x","y","ppscore"]]

# %%
pp_score = pp_score[pp_score["y"]=="selling_price"]

# %%
pp_score
# Out:
#                            x              y   ppscore
# 6                vehicle_age  selling_price  0.000000
# 16                 km_driven  selling_price  0.000000
# 26                   mileage  selling_price  0.359908
# 36                    engine  selling_price  0.354368
# 46                 max_power  selling_price  0.475222
# 56                     seats  selling_price  0.000000
# 66             selling_price  selling_price  1.000000
# 76    seller_type_Individual  selling_price  0.000000
# 86          fuel_type_Petrol  selling_price  0.000000
# 96  transmission_type_Manual  selling_price  0.006311

# %%
pp_score.sort_values(by="ppscore",ascending=False)
# Out:
#                            x              y   ppscore
# 66             selling_price  selling_price  1.000000
# 46                 max_power  selling_price  0.475222
# 26                   mileage  selling_price  0.359908
# 36                    engine  selling_price  0.354368
# 96  transmission_type_Manual  selling_price  0.006311
# 6                vehicle_age  selling_price  0.000000
# 16                 km_driven  selling_price  0.000000
# 56                     seats  selling_price  0.000000
# 76    seller_type_Individual  selling_price  0.000000
# 86          fuel_type_Petrol  selling_price  0.000000

# %% [markdown]
# ## Visualization

# %%
for column in df.columns:
    plt.hist(x=df[column])
    plt.title(column)
    plt.show()

# %%
for column in df.columns:
    df[column].plot(kind="kde")
    plt.title(column)
    plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# ## Model Building

# %%
X = df.drop(["selling_price","seller_type_Individual","km_driven","seats","transmission_type_Manual"],axis=1)

# %%
X=df[["vehicle_age","max_power","mileage","engine"]]

# %%
df.corr()
# Out:
#                           vehicle_age  km_driven   mileage    engine  \
# vehicle_age                  1.000000   0.329438 -0.263917  0.100486
# km_driven                    0.329438   1.000000 -0.107374  0.193561
# mileage                     -0.263917  -0.107374  1.000000 -0.636381
# engine                       0.100486   0.193561 -0.636381  1.000000
# max_power                    0.004986   0.044109 -0.530261  0.803590
# seats                        0.031732   0.193894 -0.450791  0.554434
# selling_price               -0.242924  -0.080094 -0.305644  0.582667
# seller_type_Individual      -0.040908   0.053723  0.089956 -0.110631
# fuel_type_Petrol            -0.009263  -0.249881 -0.116967 -0.487356
# transmission_type_Manual     0.080868   0.073347  0.281059 -0.342291
#
#                           max_power     seats  selling_price  \
# vehicle_age                0.004986  0.031732      -0.242924
# km_driven                  0.044109  0.193894      -0.080094
# mileage                   -0.530261 -0.450791      -0.305644
# engine                     0.803590  0.554434       0.582667
# max_power                  1.000000  0.168127       0.750563
# seats                      0.168127  1.000000       0.111768
# selling_price              0.750563  0.111768       1.000000
# seller_type_Individual    -0.185360  0.058073      -0.137123
# fuel_type_Petrol          -0.295267 -0.340448      -0.236351
# transmission_type_Manual  -0.537282  0.061375      -0.456341
#
#                           seller_type_Individual  fuel_type_Petrol  \
# vehicle_age                            -0.040908         -0.009263
# km_driven                               0.053723         -0.249881
# mileage                                 0.089956         -0.116967
# engine                                 -0.110631         -0.487356
# max_power                              -0.185360         -0.295267
# seats                                   0.058073         -0.340448
# selling_price                          -0.137123         -0.236351
# seller_type_Individual                  1.000000          0.017588
# fuel_type_Petrol                        0.017588          1.000000
# transmission_type_Manual                0.206425          0.021712
#
#                           transmission_type_Manual
# vehicle_age                               0.080868
# km_driven                                 0.073347
# mileage                                   0.281059
# engine                                   -0.342291
# max_power                                -0.537282
# seats                                     0.061375
# selling_price                            -0.456341
# seller_type_Individual                    0.206425
# fuel_type_Petrol                          0.021712
# transmission_type_Manual                  1.000000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = scaler.fit_transform(X)
X  = pd.DataFrame(scaled_df,columns=X.columns)

# %%
X.head()
# Out:
#    vehicle_age  max_power   mileage    engine
# 0     0.974845  -1.281554  0.030549 -1.340929
# 1    -0.349386  -0.454010 -0.166856 -0.574776
# 2     1.636961  -0.500371 -0.635691 -0.574776
# 3     0.974845  -0.799400  0.331590 -0.954987
# 4    -0.018328  -0.069445  0.788087  0.000317

# %%
# Train and test data
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(X,Y,test_size=0.2,random_state=7)

# %%
train_x
# Out:
#        vehicle_age  max_power   mileage    engine
# 7130     -0.349386   0.195044 -0.759068  0.002227
# 2369      2.630134  -0.799400 -0.166856 -0.954987
# 10812     0.643787   3.924788 -1.193358  2.856674
# 513      -1.011502  -1.111409  0.770815 -1.335198
# 7824     -1.011502  -0.407649  1.052116 -0.570955
# ...            ...        ...       ...       ...
# 5699      1.636961  -0.799400  0.331590 -0.954987
# 10742     0.974845   0.573350  0.677048  0.160808
# 537       1.305903  -0.894440 -1.474659  1.958689
# 9412      0.974845   1.910402 -0.860238  0.949888
# 12463     2.299076   0.102322 -0.882446 -0.009236
#
# [11791 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
print(r2_score(train_y,model.predict(train_x)))
print(r2_score(test_y,model.predict(test_x)))
# Out:
# 0.6177800450092916
# 0.6624895563130079

# %%
import keras

# %%
from keras.models import Sequential
from keras.layers import Dense,ReLU,Dropout

# %%
# Regression model building
model = Sequential()
model.add(Dense(units =4,kernel_initializer="he_uniform",activation="relu",input_dim=4))
model.add(Dense(units=20,kernel_initializer = "he_uniform",activation="relu"))
model.add(Dense(units=10,kernel_initializer = "he_uniform",activation= "relu"))
model.add(Dense(units=1,kernel_initializer="he_uniform"))
model.compile(
    optimizer="adam",loss="mae",metrics=["mae"])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                     │ (None, 4)                   │              20 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 20)                  │             100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 341 (1.33 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(train_x,train_y,validation_split=0.2,epochs=100)
# Out:
# Epoch 1/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 782935.3125 - mae: 782935.3125 - val_loss: 795598.9375 - val_mae: 795598.9375
# Epoch 2/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 776287.9375 - mae: 776287.9375 - val_loss: 795014.7500 - val_mae: 795014.7500
# Epoch 3/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 761911.3750 - mae: 761911.3750 - val_loss: 792470.6875 - val_mae: 792470.6875
# Epoch 4/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 756717.8125 - mae: 756717.8125 - val_loss: 786105.5000 - val_mae: 786105.5000
# Epoch 5/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 772041.0625 - mae: 772041.0625 - val_loss: 773882.6875 - val_mae: 773882.6875
# Epoch 6/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 762899.3750 - mae: 762899.3750 - val_loss: 753757.5000 - val_mae: 753757.5000
# Epoch 7/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 721528.5625 - mae: 721528.5625 - val_loss: 723787.3750 - val_mae: 723787.3750
# Epoch 8/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 709775.7500 - mae: 709775.7500 - val_loss: 682704.8750 - val_mae: 682704.8750
# Epoch 9/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 648543.2500 - mae: 648543.2500 - val_loss: 630430.4375 - val_mae: 630430.4375
# Epoch 10/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 599466.8125 - mae: 599466.8125 - val_loss: 569967.8125 - val_mae: 569967.8125
# Epoch 11/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 530925.2500 - mae: 530925.2500 - val_loss: 511309.6875 - val_mae: 511309.6875
# Epoch 12/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 500516.7812 - mae: 500516.7812 - val_loss: 466184.3438 - val_mae: 466184.3438
# Epoch 13/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 454414.3750 - mae: 454414.3750 - val_loss: 437690.2188 - val_mae: 437690.2188
# Epoch 14/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 411778.3125 - mae: 411778.3125 - val_loss: 423279.7812 - val_mae: 423279.7812
# Epoch 15/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 390231.4062 - mae: 390231.4062 - val_loss: 416916.5312 - val_mae: 416916.5312
# Epoch 16/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 406089.6250 - mae: 406089.6250 - val_loss: 414328.2812 - val_mae: 414328.2812
# Epoch 17/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 385391.9375 - mae: 385391.9375 - val_loss: 412697.4688 - val_mae: 412697.4688
# Epoch 18/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 406262.2500 - mae: 406262.2500 - val_loss: 411415.0938 - val_mae: 411415.0938
# Epoch 19/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 398930.6250 - mae: 398930.6250 - val_loss: 410137.3438 - val_mae: 410137.3438
# Epoch 20/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss:
100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 241023.0625 - mae: 241023.0625 - val_loss: 247193.6406 - val_mae: 247193.6406
# Epoch 82/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 242840.7344 - mae: 242840.7344 - val_loss: 246326.6406 - val_mae: 246326.6406
# Epoch 83/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 225583.3594 - mae: 225583.3594 - val_loss: 245580.6406 - val_mae: 245580.6406
# Epoch 84/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 228063.3906 - mae: 228063.3906 - val_loss: 244769.9375 - val_mae: 244769.9375
# Epoch 85/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 235158.4688 - mae: 235158.4688 - val_loss: 244216.4844 - val_mae: 244216.4844
# Epoch 86/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 234295.0938 - mae: 234295.0938 - val_loss: 243605.8438 - val_mae: 243605.8438
# Epoch 87/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 222568.8594 - mae: 222568.8594 - val_loss: 242959.1875 - val_mae: 242959.1875
# Epoch 88/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 236236.2500 - mae: 236236.2500 - val_loss: 242540.6250 - val_mae: 242540.6250
# Epoch 89/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 236956.1562 - mae: 236956.1562 - val_loss: 242045.9688 - val_mae: 242045.9688
# Epoch 90/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 235297.5938 - mae: 235297.5938 - val_loss: 241597.7812 - val_mae: 241597.7812
# Epoch 91/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 230322.6875 - mae: 230322.6875 - val_loss: 241375.6562 - val_mae: 241375.6562
# Epoch 92/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 237533.6406 - mae: 237533.6406 - val_loss: 240927.2500 - val_mae: 240927.2500
# Epoch 93/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 243105.9062 - mae: 243105.9062 - val_loss: 240578.3281 - val_mae: 240578.3281
# Epoch 94/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 228157.8750 - mae: 228157.8750 - val_loss: 240203.9062 - val_mae: 240203.9062
# Epoch 95/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 231470.1562 - mae: 231470.1562 - val_loss: 239929.7812 - val_mae: 239929.7812
# Epoch 96/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 222544.2812 - mae: 222544.2812 - val_loss: 239641.0156 - val_mae: 239641.0156
# Epoch 97/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 227390.0156 - mae: 227390.0156 - val_loss: 239442.0938 - val_mae: 239442.0938
# Epoch 98/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 227681.8281 - mae: 227681.8281 - val_loss: 239176.1406 - val_mae: 239176.1406
# Epoch 99/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 229814.2500 - mae: 229814.2500 - val_loss: 238953.4062 - val_mae: 238953.4062
# Epoch 100/100
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 224711.1094 - mae: 224711.1094 - val_loss: 238754.8906 - val_mae: 238754.8906

# %%
from sklearn.metrics import r2_score
print(r2_score(train_y,model.predict(train_x)))
# Out:
# 369/369 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 0.4869849681854248

# %%
print(r2_score(test_y,model.predict(test_x)))
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 0.5410587787628174

# %%
from keras_tuner import RandomSearch

# %%
def build_model(hp):
    model = Sequential()
    model.add(Dense(units =4,kernel_initializer="he_uniform",activation="relu",input_dim=4))
    for i in range(hp.Int("num_layers",1,5)):
        model.add(Dense(units=hp.Int(f"units_{i}",8,128,step=10),
                        activation="relu",
                        kernel_initializer = "he_uniform"))
        model.add(Dropout(hp.Float(f"dropout_{i}",0.1,0.5,step=0.1)))
    model.add(Dense(units=1,kernel_initializer="he_uniform"))
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice("learning_rate",[1e-1,1e-2,1e-3,1e-4])),
                  loss="mae",
                  metrics=["mae"])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective="mae",
    max_trials=10,
    executions_per_trial =3,
    directory="v6_weights",
    project_name = "car_price_prediction"
)

# %%
tuner.search(train_x,train_y,epochs=70,validation_split=0.2,batch_size=30)
# Out:
# Trial 10 Complete [00h 03m 28s]
# mae: 188391.453125
#
# Best mae So Far: 186504.90625
# Total elapsed time: 00h 53m 08s

# %%
best_model=tuner.get_best_models(num_models=1)[0]

# %%
best_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None,
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1118 - mae: 0.7500
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5571 - mae: 0.7771
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5127 - mae: 0.7981
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4771 - mae: 0.7936
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1338 - mae: 0.7470
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1409 - mae: 0.7402
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3512 - mae: 0.8241
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2439 - mae: 0.7589
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9406 - mae: 0.6835
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9185 - mae: 0.6941

# %%
print(r2_score(train_y,best_model.predict(train_x)))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 0.9578880455877175

# %%
print(r2_score(test_y,best_model.predict(test_x)))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0.9501089632391885

# %%
# Sample Prediction
from keras.models import load_model

# %%
model = load_model("model.h5")

# %%
model.summary()

# %%
year = 2021
present_Price = 12
Fuel_Type = "Petrol"
Seller_Type = "Individudal"
fuel = 1 if Fuel_Type == "Petrol" else 0
seller = 1 if Seller_Type == "Individual" else 0
age = 2024 -year

# %%
X.columns
# Out:
# Index(['Present_Price', 'age', 'Fuel_Type_Petrol', 'Seller_Type_Individual'], dtype='object')

# %%
input = {
    "Present_Price":[present_Price],
    "age":[age],
    "Fuel_Type_Petrol":[fuel],
    "Seller_Type_Individual":[seller]
    
}
data = pd.DataFrame(input)
scaler_1 = joblib.load("scaler.pkl")
scaled = scaler_1.transform(data)
data_input = pd.DataFrame(scaled,columns=data.columns)

# %%
best_model.predict(data_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# array([[15.796814]], dtype=float32)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 4)                   │              20 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 20)                  │             100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,025 (4.01 KB)
#  Trainable params: 341 (1.33 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 684 (2.68 KB)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
randomforest = RandomForestRegressor()

# %%
randomforest.fit(train_x,train_y)
# Out:
# RandomForestRegressor()

# %%
print(r2_score(train_y,randomforest.predict(train_x)))
# Out:
# 0.9682872529404657

# %%
print(r2_score(test_y,randomforest.predict(test_x)))
# Out:
# 0.9256056282835641

# %%
params = {
    "n_estimators":[10,20,30,50,100,150,200],
    "min_samples_split":[3,4,5,6,7]
}

# %%
gridsearch = GridSearchCV(estimator = randomforest,param_grid = params,scoring="accuracy",n_jobs=-1)

# %%
gridsearch.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'min_samples_split': [3, 4, 5, 6, 7],
#                          'n_estimators': [10, 20, 30, 50, 100, 150, 200]},
#              scoring='accuracy')

# %%
gridsearch.best_params_
# Out:
# {'min_samples_split': 3, 'n_estimators': 10}

# %%
model =RandomForestRegressor(min_samples_split=3,n_estimators=10)

# %%
model
# Out:
# RandomForestRegressor(min_samples_split=3, n_estimators=10)

# %%
model.fit(train_x,train_y)
# Out:
# RandomForestRegressor(min_samples_split=3, n_estimators=10)

# %%
print(r2_score(train_y,model.predict(train_x)))
# Out:
# 0.964921001375007

# %%
print(r2_score(test_y,model.predict(test_x)))
# Out:
# 0.9287691171100183

# %% [markdown]
# ## Saving the model and standardizer.

# %%
joblib.dump(model,"model.pkl")
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
scaler=joblib.load("scaler.pkl")
model = joblib.load("model.pkl")

# %%
inputs={
    "vehicle_age":[9],
    "max_power":[46.30],
    "mileage":[19.70],
    "engine":[796]
}
inputs= pd.DataFrame(inputs)

# %%
scaled_input = scaler.transform(inputs)
input = pd.DataFrame(scaled_input,columns=inputs.columns)

# %%
prediction = model.predict(input)

# %%
prediction
# Out:
# array([13228333.33333333])
